# %%
import cv2

# %%
face_cap = cv2.CascadeClassifier("C:/Users/lucif/anaconda3/Lib/site-packages/cv2/datahaarcascade_frontalface_default.xml")
video_cap  = cv2.VideoCapture(0)
while True:
    ret , video_data = video_cap.read()
    col = cv2.cvtColor(video_data,cv2.COLOR_BGR2GRAY)
    faces = face_cap.detectMultiScale(
        col,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30),
        flags=cv2.CASCADE_SCALE_IMAGE
    )
    for (x,y,w,h) in faces:
        cv2.rectangle(video_data, (x,y),(x+w,y+h),(0,255,0),2)
    cv2.imshow("video_live", video_data)
    if cv2.waitKey(10) == ord("a"):
        break
video_cap.release()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 5
#       3 while True:
#       4     ret , video_data = video_cap.read()
# ----> 5     col = cv2.cvtColor(video_data,cv2.COLOR_BGR2GRAY)
#       6     faces = face_cap.detectMultiScale(
#       7         col,
#       8         scaleFactor=1.1,
#    (...)
#      11         flags=cv2.CASCADE_SCALE_IMAGE
#      12     )
#      13     for (x,y,w,h) in faces:
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
